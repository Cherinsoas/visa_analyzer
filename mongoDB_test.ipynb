# %% [markdown]
# <a href="https://colab.research.google.com/github/Cherinsoas/visa_analyzer/blob/main/mongoDB_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Ok")
# Out:
# Ok

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Visadataset.csv")
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.shape
# Out:
# (25480, 12)

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'case_id': 'EZYV01',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 14513,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 592.2029,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV02',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2412,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 83425.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV03',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 44444,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'West',
# ...

# %%
len(data)
# Out:
# 25480

# %%
DB_NAME = "VISA_APPLICATION_DATA"
COLLECTION_NAME = "visa_data"
CONNECTION_URL = "mongodb+srv://gcheria:gcheria@cluster0.lhkmpoc.mongodb.net/?appName=Cluster0"

# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 11.1 MB/s eta 0:00:00
# ...

# %%
import pymongo

client = pymongo.MongoClient(CONNECTION_URL)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('698de719416817ae7a41ad7f'), ObjectId('698de719416817ae7a41ad80'), ObjectId('698de719416817ae7a41ad81'), ObjectId('698de719416817ae7a41ad82'), ObjectId('698de719416817ae7a41ad83'), ObjectId('698de719416817ae7a41ad84'), ObjectId('698de719416817ae7a41ad85'), ObjectId('698de719416817ae7a41ad86'), ObjectId('698de719416817ae7a41ad87'), ObjectId('698de719416817ae7a41ad88'), ObjectId('698de719416817ae7a41ad89'), ObjectId('698de719416817ae7a41ad8a'), ObjectId('698de719416817ae7a41ad8b'), ObjectId('698de719416817ae7a41ad8c'), ObjectId('698de719416817ae7a41ad8d'), ObjectId('698de719416817ae7a41ad8e'), ObjectId('698de719416817ae7a41ad8f'), ObjectId('698de719416817ae7a41ad90'), ObjectId('698de719416817ae7a41ad91'), ObjectId('698de719416817ae7a41ad92'), ObjectId('698de719416817ae7a41ad93'), ObjectId('698de719416817ae7a41ad94'), ObjectId('698de719416817ae7a41ad95'), ObjectId('698de719416817ae7a41ad96'), ObjectId('698de719416817ae7a41ad97'), ObjectId('698de719416817ae7a41
# ...

# %% [markdown]
# # Get data from db

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i} : {j}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 20480 : {'_id': ObjectId('698de71a416817ae7a41fd7f'), 'case_id': 'EZYV20481', 'continent': 'Europe', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2184, 'yr_of_estab': 2012, 'region_of_employment': 'West', 'prevailing_wage': 11323.59, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 20481 : {'_id': ObjectId('698de71a416817ae7a41fd80'), 'case_id': 'EZYV20482', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 452, 'yr_of_estab': 1997, 'region_of_employment': 'West', 'prevailing_wage': 153531.71, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# ...

# %%
df = pd.DataFrame(list(collection.find()))

# %%
df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  698de719416817ae7a41ad7f  EZYV01      Asia           High School
# 1  698de719416817ae7a41ad80  EZYV02      Asia              Master's
# 2  698de719416817ae7a41ad81  EZYV03      Asia            Bachelor's
# 3  698de719416817ae7a41ad82  EZYV04      Asia            Bachelor's
# 4  698de719416817ae7a41ad83  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# ...

# %%
if "_id" in df.columns:
    df.drop(columns=["_id"], inplace=True)

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...
